# %% [markdown]
# # Библиотеки для машинного обучения
#
# ## Scikit-learn
# https://github.com/DLSchool/deep-learning-school/blob/fall_2021_part1/05_ML_basics/%5Bseminar%5Dml_basics.ipynb

# %%
import pandas as pd

data = pd.read_csv('data.csv', index_col='PassengerId')
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# Splitting up the Training Data
# Now its time for some Machine Learning.
#
# First, separate the features(X) from the labels(y).
#
# X_all: All features minus the value we want to predict (Survived).
#
# y_all: Only the value we want to predict.
#
# Second, use Scikit-learn to randomly shuffle this data into four variables. In this case, I'm training 80% of the data, then testing against the other 20%.

# %%
from sklearn.model_selection import train_test_split

data_ = data[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]

X = data_.drop(['Survived'], axis=1)
y = data_['Survived']

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.20, 
    random_state=23
)

# %% [markdown]
# Fitting and Tuning an Algorithm
# Now it's time to figure out which algorithm is going to deliver the best model. I'm going with the RandomForestClassifier, but you can drop any other classifier here, such as Support Vector Machines or Naive Bayes.

# %%
data_
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500
# ...               ...     ...   ...    ...    ...      ...
# 887                 0       2  27.0      0      0  13.0000
# 888                 1       1  19.0      0      0  30.0000
# 889                 0       3   NaN      1      2  23.4500
# 890                 1       1  26.0      0      0  30.0000
# 891                 0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV

# Choose some parameter combinations to try
parameters = {
    'n_estimators': 4, 
    'max_features': 'log2', 
    'criterion': 'entropy',
    'max_depth': 2, 
    'min_samples_split': 2,
    'min_samples_leaf': 1
}

# Choose the type of classifier. 
clf = RandomForestClassifier(**parameters)

# Fit the best algorithm to the data. 
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=2, max_features='log2',
#                        n_estimators=4)

# %%
predictions = clf.predict(X_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.7206703910614525

# %% [markdown]
# # Библиотеки для глубинного обучения

# %% [markdown]
# ## PyTorch

# %%
# TODO

# %% [markdown]
# https://github.com/DLSchool/deep-learning-school/blob/fall_2021_part1/08_Neural_networks_basics_Pytorch/%5Bseminar%5Dpytorch_basics.ipynb
# https://github.com/DLSchool/deep-learning-school/blob/fall_2021_part1/08_Neural_networks_basics_Pytorch/%5Bseminar%5Dpytorch_simple_NN.ipynb

# %% [markdown]
# ## TensorFlow

# %%
# TODO

# %% [markdown]
# # Библиотеки для решения задачи комьютерного зрения

# %%
# TODO

# %% [markdown]
# ## Scikit-image

# %%
# TODO

# %% [markdown]
# # opencv

# %%
# TODO

# %% [markdown]
# # Библиотеки для обработки ествественного языка

# %%
# TODO

# %% [markdown]
# ## Nltk

# %%
# TODO

# %% [markdown]
# ## Spacy

# %%
# TODO

# %% [markdown]
# ## etc..

# %%
# TODO
